# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split  # 数据划分
from sklearn.metrics import mean_squared_error  # 均方误差

# %%
plt.style.use('ggplot')

# %%
data = pd.read_csv('./dataset/Advertising.csv')

# %%
plt.scatter(data.TV, data.sales)

# %%
plt.scatter(data.radio, data.sales)

# %%
plt.scatter(data.newspaper, data.sales)

# %%
data
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
x = data[['TV','radio','newspaper']]

# %%
y = data.sales

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
len(x_train),len(y_train)
# Out:
# (150, 150)

# %%
len(x_test)
# Out:
# 50

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([0.04360884, 0.1919157 , 0.00078185])

# %%
for i in zip(x_train.columns, model.coef_):
    print(i)
# Out:
# ('TV', 0.0436088434424217)
# ('radio', 0.19191569983572265)
# ('newspaper', 0.0007818490609210749)

# %%
mean_squared_error(model.predict(x_test), y_test)
# Out:
# 4.171246979713524

# %% [markdown]
# # 模型改进

# %%
x = data[['TV', 'radio']]

# %%
y = data.sales

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
model2 = LinearRegression()

# %%
model2.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model2.coef_
# Out:
# array([0.04662603, 0.17581585])

# %%
mean_squared_error(model2.predict(x_test),y_test)
# Out:
# 3.2629269821059164

# %% [markdown]
# 所以并不是特征越多越好
