# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 数据加载

# %%
data = pd.read_csv('./dataset/air1908.csv')
# data = pd.read_csv('./dataset/air1908.csv', head=None) # 第一行就是数据，没有表头时

# %%
data.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5268 non-null   object
#  1   Time          3049 non-null   object
#  2   Location      5248 non-null   object
#  3   Operator      5250 non-null   object
#  4   Flight #      1069 non-null   object
#  5   Route         3562 non-null   object
#  6   Type          5241 non-null   object
#  7   Registration  4933 non-null   object
#  8   cn/In         4040 non-null   object
#  9   Aboard        5246 non-null   float64
#  10  Fatalities    5256 non-null   float64
#  11  Ground        5246 non-null   float64
#  12  Summary       4878 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 535.2+ KB

# %%
data = pd.read_csv('./dataset/datingTestSet2.txt', 
                   sep='\t', header=None, 
                   names=['age', 'name', 'height', 'sex'])
# names=['age', 'name', 'height', 'sex'] 指定列名

# %%
data
# Out:
#        age       name    height  sex
# 0    40920   8.326976  0.953952    3
# 1    14488   7.153469  1.673904    2
# 2    26052   1.441871  0.805124    1
# 3    75136  13.147394  0.428964    1
# 4    38344   1.669788  0.134296    1
# ..     ...        ...       ...  ...
# 995  11145   3.410627  0.631838    2
# 996  68846   9.974715  0.669787    1
# 997  26575  10.650102  0.866627    3
# 998  48111   9.134528  0.728045    3
# 999  43757   7.882601  1.332446    3
#
# [1000 rows x 4 columns]

# %%
data = pd.read_csv('./dataset/air1908.csv', index_col='Date')

# %%
data.index
# Out:
# Index(['09/17/1908', '07/12/1912', '08/06/1913', '09/09/1913', '10/17/1913',
#        '03/05/1915', '09/03/1915', '07/28/1916', '09/24/1916', '10/01/1916',
#        ...
#        '04/09/2009', '04/17/2009', '04/17/2009', '04/29/2009', '05/03/2009',
#        '05/20/2009', '05/26/2009', '06/01/2009', '06/07/2009', '06/08/2009'],
#       dtype='object', name='Date', length=5268)

# %%
data.columns
# Out:
# Index(['Time', 'Location', 'Operator', 'Flight #', 'Route', 'Type',
#        'Registration', 'cn/In', 'Aboard', 'Fatalities', 'Ground', 'Summary'],
#       dtype='object')

# %% [markdown]
# # 数据存储

# %%
data.tail()
# Out:
#              Time                                           Location  \
# Date
# 05/20/2009  06:30                             Near Madiun, Indonesia
# 05/26/2009    NaN                  Near Isiro, DemocratiRepubliCongo
# 06/01/2009  00:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 06/07/2009  08:30       Near Port Hope Simpson, Newfoundland, Canada
# 06/08/2009    NaN                  State of Arunachal Pradesh, India
#
#                                    Operator Flight #  \
# Date
# 05/20/2009  Military - Indonesian Air Force      NaN
# 05/26/2009                      Service Air      NaN
# 06/01/2009                       Air France      447
# 06/07/2009                       Strait Air      NaN
# 06/08/2009      Military - Indian Air Force      NaN
#
#                                                 Route  \
# Date
# 05/20/2009                           Jakarta - Maduin
# 05/26/2009                               Goma - Isiro
# ...

# %%
data.to_csv('./dataset/my_data.csv')

# %%
data = pd.read_csv('./dataset/datingTestSet2.txt', 
                   sep='\t', header=None, 
                   names=['age', 'name', 'height', 'sex'])

# %%
data.to_csv('./dataset/my_data2.csv')

# %%
data2 = pd.read_csv('./dataset/my_data2.csv')

# %%
data2
# Out:
#      Unnamed: 0    age       name    height  sex
# 0             0  40920   8.326976  0.953952    3
# 1             1  14488   7.153469  1.673904    2
# 2             2  26052   1.441871  0.805124    1
# 3             3  75136  13.147394  0.428964    1
# 4             4  38344   1.669788  0.134296    1
# ..          ...    ...        ...       ...  ...
# 995         995  11145   3.410627  0.631838    2
# 996         996  68846   9.974715  0.669787    1
# 997         997  26575  10.650102  0.866627    3
# 998         998  48111   9.134528  0.728045    3
# 999         999  43757   7.882601  1.332446    3
#
# [1000 rows x 5 columns]

# %%
data.to_csv('./dataset/my_data3.csv', index=False)

# %%
data3 = pd.read_csv('./dataset/my_data3.csv')

# %%
data3
# Out:
#        age       name    height  sex
# 0    40920   8.326976  0.953952    3
# 1    14488   7.153469  1.673904    2
# 2    26052   1.441871  0.805124    1
# 3    75136  13.147394  0.428964    1
# 4    38344   1.669788  0.134296    1
# ..     ...        ...       ...  ...
# 995  11145   3.410627  0.631838    2
# 996  68846   9.974715  0.669787    1
# 997  26575  10.650102  0.866627    3
# 998  48111   9.134528  0.728045    3
# 999  43757   7.882601  1.332446    3
#
# [1000 rows x 4 columns]

# %%
data3.to_excel('./dataset/my_ex.xlsx')

# %%
data3.to_excel('./dataset/my_ex2.xlsx', index=False)

# %%
data4 = pd.read_excel('./dataset/my_ex2.xlsx')

# %%
data4
# Out:
#        age       name    height  sex
# 0    40920   8.326976  0.953952    3
# 1    14488   7.153469  1.673904    2
# 2    26052   1.441871  0.805124    1
# 3    75136  13.147394  0.428964    1
# 4    38344   1.669788  0.134296    1
# ..     ...        ...       ...  ...
# 995  11145   3.410627  0.631838    2
# 996  68846   9.974715  0.669787    1
# 997  26575  10.650102  0.866627    3
# 998  48111   9.134528  0.728045    3
# 999  43757   7.882601  1.332446    3
#
# [1000 rows x 4 columns]

# %%
data5 = pd.read_excel('./dataset/my_ex3.xlsx', sheet_name=1)

# %%
data5.head()
# Out:
#      age       name    height  sex
# 0  40920   8.326976  0.953952    3
# 1  14488   7.153469  1.673904    2
# 2  26052   1.441871  0.805124    1
# 3  75136  13.147394  0.428964    1
# 4  38344   1.669788  0.134296    1

# %% [raw]
# data5.to_json()
# data5.read_json()
